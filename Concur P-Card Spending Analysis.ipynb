# %% [markdown]
# # Concur P-Card Spending Analysis

# %% [markdown]
# This notebook contains basic cleaning operations on a sample of the Concur P-Spend Data. We hope that in cleaning, we will be able to group transactions by supplier to better represent spending by supplier.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import openpyxl

# %% [markdown]
# ## Downloading the Data

# %% [markdown]
# **Note**: We will be working with only the description column from the data set, as I wasn't able to pull the entire dataset from Oracle without surpassing the data limit.

# %%
oracle = pd.read_excel('concur_data.xlsx')

# %% [markdown]
# ## Basic Cleaning

# %% [markdown]
# **Shape:** Before we begin basic cleaning, lets take a look at how many rows our data seems to have.

# %%
oracle.shape
# Out:
# (581548, 20)

# %% [markdown]
# **Correcting Columns:** Next, we can take this data and correct all the column names so that they reflect what is presented in oracle and on the databases.

# %%
oracle.columns = ['Invoice ID',
                   'Invoice Number', 
                   'Invoice Source', 
                   'Description', 
                   'Invoice Distribution Amount', 
                   'Invoice Creation Date',
                   'Supplier Invoice Date',
                   'Payment Date',
                   'Payment Method Code',
                   'Payment Number',
                   'Supplier Name',
                   'Financial Unit',
                   'Financial Unit Number',
                   'Financial Unit Number Level 2',
                   'Financial Unit Name Level 2',
                   'Financial Unit Number Level 3',
                   'Financial Unit Name Level 3',
                   'Financial Unit Number Level 4',
                   'Financial Unit Name Level 4',
                   'Payment Year']

# %% [markdown]
# **What does our data look like?** Lets sample ten rows of our data to see what it looks like

# %%
oracle.sample(10)
# Out:
#        Invoice ID                                    Invoice Number  \
# 194082    3891982        TE_2B0D026622054DB59313_T_BeckmeyerHillary
# 550448    6656326          TE_88EE2024BF8D43B29FEF_P_TruongJennifer
# 192137    3882975                 TE_730B0E1A123E48058277_T_DeanJon
# 119784    3272996  TE_ABE422DCBE624847BE2C_P_Garcia SevillanoCarmen
# 303385    4941565        TE_764F6349E5584BB689B3_P_SalinasFrancisco
# 138912    3423774           TE_881BA1B4864A46CF907B_P_DereusJeffrey
# 238026    4314680              TE_CFDE4E2BD4284DFDB8A5_T_HobanBryan
# 359184    5409415            TE_0F919D1722E743168A9F_T_GnannJeffrey
# 302696    4939471       TE_B037C655AA3F4C0D9870_T_CederquistLynette
# 361075    5433880            TE_DF6500FB48514C4AB887_P_CoufalNicole
#
#        Invoice Source                                        Description  \
# 194082    UCSD Concur                                 Airfare||Southwest
# 550448    UCSD Concur  522600 - Fed Chargeable - Subscriptions and Me...
# 192137    UCSD Concur               Train/Bus||ACCESRAI    L  1778878907
# 119784    UCSD Concur                Food, Ships Operation||RALPHS #0108
# 303385    UCSD Concur                         Office Supplies||436486629
# 138912    UCSD Concur            Office Supplies||UC SAN DIEGO BOOKSTORE
# 238026    UCSD Concur                             Hotel Tax||THE VILLAGE
# 359184    UCSD Concur                           Airfare||United Airlines
# 302696    UCSD Concur                             Hotel Tax||THE JUPITER
# 361075    UCSD Concur             Lab Supplies||UVIC ACCT SERVICES ECOMM
#
#        Invoice Distribution Amount          Invoice Creation Date  \
# 194082                      336.34  2022-12-10T05:15:57.000+00:00
# 550448                      323.88  2024-07-05T02:37:13.000+00:00
# 192137                          72  2022-12-08T04:16:59.000+00:00
# 119784                      107.72  2022-07-06T03:05:58.000+00:00
# 303385                       55.99  2023-06-14T03:41:27.000+00:00
# 138912                       31.23  2022-08-23T03:06:00.000+00:00
# 238026                      149.67  2023-03-10T04:06:18.000+00:00
# 359184                      155.24  2023-09-21T04:09:46.000+00:00
# 302696                       52.35  2023-06-13T22:09:25.000+00:00
# 361075                     1628.28  2023-09-23T03:12:39.000+00:00
#
#                 Supplier Invoice Date                   Payment Date  \
# 194082  2022-06-04T00:00:00.000+00:00  2022-12-11T00:00:00.000+00:00
# 550448  2024-06-27T00:00:00.000+00:00  2024-07-06T00:00:00.000+00:00
# 192137  2022-09-02T00:00:00.000+00:00  2022-12-09T00:00:00.000+00:00
# 119784  2022-05-19T00:00:00.000+00:00  2022-07-07T00:00:00.000+00:00
# 303385  2023-01-21T00:00:00.000+00:00  2023-06-15T00:00:00.000+00:00
# 138912  2022-06-30T00:00:00.000+00:00  2022-08-24T00:00:00.000+00:00
# 238026  2022-10-17T00:00:00.000+00:00  2023-03-11T00:00:00.000+00:00
# 359184  2023-08-15T00:00:00.000+00:00  2023-09-22T00:00:00.000+00:00
# 302696  2023-02-16T00:00:00.000+00:00  2023-06-14T00:00:00.000+00:00
# 361075  2023-09-12T00:00:00.000+00:00  2023-09-24T00:00:00.000+00:00
#
#        Payment Method Code Payment Number                Supplier Name  \
# 194082                  TC         679738  Concur Campus Card Clearing
# 550448                  EC        1115068  Concur Campus Card Clearing
# 192137                  TC         679058  Concur Campus Card Clearing
# 119784                  EC         575619  Concur Campus Card Clearing
# 303385                  EC         811006  Concur Campus Card Clearing
# 138912                  EC         599241  Concur Campus Card Clearing
# 238026                  TC         741915  Concur Campus Card Clearing
# 359184                  TC         868997  Concur Campus Card Clearing
# 302696                  TC         810566  Concur Campus Card Clearing
# 361075                  EC         869818  Concur Campus Card Clearing
#
#                                           Financial Unit  \
# 194082                                             CASPO
# 550448                  Computer Science and Engineering
# 192137                                 HS Anesthesiology
# 119784                      School of Public Health Dept
# 303385                  Early Academic Outreach Programs
# 138912  Pediatrics Host Microbe Systems and Therapeutics
# 238026                              Geosciences Research
# 359184                                Utility Enterprise
# 302696                       Balance Sheet Accounts only
# 361075        Pediatrics Allergy/Immunology/Rheumatology
#
#        Financial Unit Number Financial Unit Number Level 2  \
# 194082               2000020                       200000A
# 550448               1000177                       100000A
# 192137               3000008                       300000A
# 119784               3000191                       300000A
# 303385               1000153                       100000A
# 138912               3000062                       300000A
# 238026               2000016                       200000A
# 359184               7000015                       700000A
# 302696               4200100                       420000A
# 361075               3000048                       300000A
#
#              Financial Unit Name Level 2 Financial Unit Number Level 3  \
# 194082                    Marine Science                       200100B
# 550448                  Academic Affairs                       100800B
# 192137                    Health Science                       300200B
# 119784                    Health Science                       300700B
# 303385                  Academic Affairs                       100600B
# 138912                    Health Science                       300200B
# 238026                    Marine Science                       200100B
# 359184  Resource Management and Planning                       700300B
# 302696             CEO of Medical Center                       421000B
# 361075                    Health Science                       300200B
#
#        Financial Unit Name Level 3 Financial Unit Number Level 4  \
# 194082    Marine Sciences Research                       200104C
# 550448         Dean of Engineering                       100803C
# 192137          School of Medicine                       300202C
# 119784     School of Public Health                       300700C
# 303385     Dean of Social Sciences                       100606C
# 138912          School of Medicine                       300209C
# 238026    Marine Sciences Research                       200103C
# 359184       Facilities Management                       700307C
# 302696                         CFO                       421000C
# 361075          School of Medicine                       300209C
#
#                 Financial Unit Name Level 4 Payment Year
# 194082                 Ocean and Atmosphere         2022
# 550448     Computer Science and Engineering         2024
# 192137                       Anesthesiology         2022
# 119784              School of Public Health         2022
# 303385  Ctr Res Educ Equity Asses/Teach Exc         2023
# 138912                           Pediatrics         2022
# 238026                       Earth Sciences         2023
# 359184                   Utility Enterprise         2023
# 302696                Institutional Expense         2023
# 361075                           Pediatrics         2023

# %% [markdown]
# **Getting the entries we want**: Oracle has a tendency to export the title of invoices as a row under the invoice to avoid these entries, since they are generally incorrectly formatted, we will filter out any row that has an invoice distribution number of 0.

# %%
oracle = oracle.drop(index = 0)
oracle = oracle.reset_index(drop = True)
oracle_clean = oracle.dropna(subset=['Description'])
oracle = oracle_clean[oracle_clean['Invoice Distribution Amount'] != 0]

# %% [markdown]
# **Inconsistencies:** We are looking at the description column to identify suppliers for each row. Lets see how many of the description columns deviate from the format "Supplier || Description".

# %%
oracle_incorrect = oracle_clean[~oracle_clean['Description'].str.contains('\|\|')]
oracle_incorrect.sample(10)
# Out:
#        Invoice ID             Invoice Number Invoice Source  \
# 334691    5231127   TE_GHM4_G_WilsonErickson    UCSD Concur
# 519827    6492602      TE_KRK4_G_LewisLeslie    UCSD Concur
# 282474    4813681    TE_FJVH_G_SarikWathnita    UCSD Concur
# 958       2056734         TE_4FYM_G_EdgeLori    UCSD Concur
# 326354    5173434    TE_G3HV_G_OjedaVictoria    UCSD Concur
# 223835    4241081   TE_9HLG_G_BenariehTaylor    UCSD Concur
# 489856    6383793  TE_JVNX_G_SanchezJoseline    UCSD Concur
# 346473    5305668  TE_GL47_G_MancanoJennifer    UCSD Concur
# 468606    6219220   TE_JWJR_G_HernandezAlexa    UCSD Concur
# 173678    3766320       TE_7TEP_G_LozanoJohn    UCSD Concur
#
#                                     Description Invoice Distribution Amount  \
# 334691                 Gift Cards - HS Payments                        5200
# 519827  536300 - Gifts/Awards For Non-Employees                         505
# 282474                 Gift Cards - HS Payments                        2550
# 958                    Gift Cards - HS Payments                      2557.5
# 326354                 Gift Cards - HS Payments                        1050
# 223835          Non-Employee - Gift/Prize/Award                         303
# 489856          Non-Employee - Gift/Prize/Award                         765
# 346473          Non-Employee - Gift/Prize/Award                         985
# 468606                 Gift Cards - HS Payments                        2785
# 173678              Employee - Gift/Prize/Award                          51
#
#                 Invoice Creation Date          Supplier Invoice Date  \
# 334691  2023-08-05T04:10:48.000+00:00  2023-08-05T00:00:00.000+00:00
# 519827  2024-06-01T03:11:46.000+00:00  2024-06-01T00:00:00.000+00:00
# 282474  2023-05-20T03:18:20.000+00:00  2023-05-20T00:00:00.000+00:00
# 958     2021-09-14T05:56:26.000+00:00  2021-09-14T00:00:00.000+00:00
# 326354  2023-07-20T03:18:35.000+00:00  2023-07-20T00:00:00.000+00:00
# 223835  2023-02-11T04:10:31.000+00:00  2023-02-11T00:00:00.000+00:00
# 489856  2024-04-20T03:20:41.000+00:00  2024-04-20T00:00:00.000+00:00
# 346473  2023-08-29T03:17:51.000+00:00  2023-08-29T00:00:00.000+00:00
# 468606  2024-03-21T03:10:54.000+00:00  2024-03-21T00:00:00.000+00:00
# 173678  2022-11-05T04:10:26.000+00:00  2022-11-05T00:00:00.000+00:00
#
#                          Payment Date Payment Method Code Payment Number  \
# 334691  2023-08-06T00:00:00.000+00:00                Gift         846313
# 519827  2024-06-02T00:00:00.000+00:00                Gift        1093234
# 282474  2023-05-21T00:00:00.000+00:00                Gift         796017
# 958     2021-09-15T00:00:00.000+00:00                Gift         315453
# 326354  2023-07-21T00:00:00.000+00:00                Gift         834943
# 223835  2023-02-12T00:00:00.000+00:00                Gift         726282
# 489856  2024-04-21T00:00:00.000+00:00                Gift        1069108
# 346473  2023-08-30T00:00:00.000+00:00                Gift         859094
# 468606  2024-03-22T00:00:00.000+00:00                Gift        1015376
# 173678  2022-11-06T00:00:00.000+00:00                Gift         657197
#
#                       Supplier Name  \
# 334691  Concur Campus Card Clearing
# 519827  Concur Campus Card Clearing
# 282474  Concur Campus Card Clearing
# 958     Concur Campus Card Clearing
# 326354  Concur Campus Card Clearing
# 223835  Concur Campus Card Clearing
# 489856  Concur Campus Card Clearing
# 346473  Concur Campus Card Clearing
# 468606  Concur Campus Card Clearing
# 173678  Concur Campus Card Clearing
#
#                                          Financial Unit Financial Unit Number  \
# 334691                           Biomedical Informatics               3000025
# 519827                                  Urban and Rural               1000170
# 282474                        Medicine Gastroenterology               3000013
# 958                           Medicine Gastroenterology               3000013
# 326354                     School of Public Health Dept               3000191
# 223835                                    Communication               1000149
# 489856  Obstetrics Gynecology and Reproductive Sciences               3000087
# 346473                                      CPEO Events               6000042
# 468606                                HS Anesthesiology               3000008
# 173678                                Political Science               1000167
#
#        Financial Unit Number Level 2 Financial Unit Name Level 2  \
# 334691                       300000A              Health Science
# 519827                       100000A            Academic Affairs
# 282474                       300000A              Health Science
# 958                          300000A              Health Science
# 326354                       300000A              Health Science
# 223835                       100000A            Academic Affairs
# 489856                       300000A              Health Science
# 346473                       600000A             Student Affairs
# 468606                       300000A              Health Science
# 173678                       100000A            Academic Affairs
#
#        Financial Unit Number Level 3 Financial Unit Name Level 3  \
# 334691                       300200B          School of Medicine
# 519827                       100600B     Dean of Social Sciences
# 282474                       300200B          School of Medicine
# 958                          300200B          School of Medicine
# 326354                       300700B     School of Public Health
# 223835                       100600B     Dean of Social Sciences
# 489856                       300200B          School of Medicine
# 346473                       600100B                Student LIfe
# 468606                       300200B          School of Medicine
# 173678                       100600B     Dean of Social Sciences
#
#        Financial Unit Number Level 4  \
# 334691                       300204C
# 519827                       100607C
# 282474                       300204C
# 958                          300204C
# 326354                       300700C
# 223835                       100605C
# 489856                       300212C
# 346473                       600103C
# 468606                       300202C
# 173678                       100615C
#
#                             Financial Unit Name Level 4 Payment Year
# 334691                                         Medicine         2023
# 519827                                  Urban and Rural         2024
# 282474                                         Medicine         2023
# 958                                            Medicine         2021
# 326354                          School of Public Health         2023
# 223835                                   Communications         2023
# 489856  Obstetrics Gynecology and Reproductive Sciences         2024
# 346473                                         ArtPower         2023
# 468606                                   Anesthesiology         2024
# 173678                                Political Science         2022

# %%
oracle_incorrect.shape[0]
# Out:
# 3702

# %% [markdown]
# **Quantifying Inconsistencies**: Now that we have found out how many inconsistencies we have in our data, the next step is finding out how those inconsistences are distributed through out the data. We can do this by taking each weirdly formatted supplier and seeing how many times they appear, that way we can correct for the common ones and then do away with the uncommon ones.

# %%
oracle_incorrect.groupby('Description').count().sort_values('Invoice ID', ascending = False).head(6)
# Out:
#                                          Invoice ID  Invoice Number  \
# Description
# Gift Cards - HS Payments                       1468            1468
# Employee - Gift/Prize/Award                    1102            1102
# Non-Employee - Gift/Prize/Award                 461             461
# 535100 - Human Subjects (Gift Card)             242             242
# 536200 - Gifts/Awards For Employees             210             210
# 536300 - Gifts/Awards For Non-Employees          79              79
#
#                                          Invoice Source  \
# Description
# Gift Cards - HS Payments                           1468
# Employee - Gift/Prize/Award                        1102
# Non-Employee - Gift/Prize/Award                     461
# 535100 - Human Subjects (Gift Card)                 242
# 536200 - Gifts/Awards For Employees                 210
# 536300 - Gifts/Awards For Non-Employees              79
#
#                                          Invoice Distribution Amount  \
# Description
# Gift Cards - HS Payments                                        1468
# Employee - Gift/Prize/Award                                     1102
# Non-Employee - Gift/Prize/Award                                  461
# 535100 - Human Subjects (Gift Card)                              242
# 536200 - Gifts/Awards For Employees                              210
# 536300 - Gifts/Awards For Non-Employees                           79
#
#                                          Invoice Creation Date  \
# Description
# Gift Cards - HS Payments                                  1468
# Employee - Gift/Prize/Award                               1102
# Non-Employee - Gift/Prize/Award                            461
# 535100 - Human Subjects (Gift Card)                        242
# 536200 - Gifts/Awards For Employees                        210
# 536300 - Gifts/Awards For Non-Employees                     79
#
#                                          Supplier Invoice Date  Payment Date  \
# Description
# Gift Cards - HS Payments                                  1468          1468
# Employee - Gift/Prize/Award                               1102          1102
# Non-Employee - Gift/Prize/Award                            461           461
# 535100 - Human Subjects (Gift Card)                        242           242
# 536200 - Gifts/Awards For Employees                        210           210
# 536300 - Gifts/Awards For Non-Employees                     79            79
#
#                                          Payment Method Code  Payment Number  \
# Description
# Gift Cards - HS Payments                                1468            1468
# Employee - Gift/Prize/Award                             1102            1102
# Non-Employee - Gift/Prize/Award                          461             461
# 535100 - Human Subjects (Gift Card)                      242             242
# 536200 - Gifts/Awards For Employees                      210             210
# 536300 - Gifts/Awards For Non-Employees                   79              79
#
#                                          Supplier Name  Financial Unit  \
# Description
# Gift Cards - HS Payments                          1468            1468
# Employee - Gift/Prize/Award                       1102            1102
# Non-Employee - Gift/Prize/Award                    461             461
# 535100 - Human Subjects (Gift Card)                242             242
# 536200 - Gifts/Awards For Employees                210             210
# 536300 - Gifts/Awards For Non-Employees             79              79
#
#                                          Financial Unit Number  \
# Description
# Gift Cards - HS Payments                                  1468
# Employee - Gift/Prize/Award                               1102
# Non-Employee - Gift/Prize/Award                            461
# 535100 - Human Subjects (Gift Card)                        242
# 536200 - Gifts/Awards For Employees                        210
# 536300 - Gifts/Awards For Non-Employees                     79
#
#                                          Financial Unit Number Level 2  \
# Description
# Gift Cards - HS Payments                                          1468
# Employee - Gift/Prize/Award                                       1102
# Non-Employee - Gift/Prize/Award                                    461
# 535100 - Human Subjects (Gift Card)                                242
# 536200 - Gifts/Awards For Employees                                210
# 536300 - Gifts/Awards For Non-Employees                             79
#
#                                          Financial Unit Name Level 2  \
# Description
# Gift Cards - HS Payments                                        1468
# Employee - Gift/Prize/Award                                     1102
# Non-Employee - Gift/Prize/Award                                  461
# 535100 - Human Subjects (Gift Card)                              242
# 536200 - Gifts/Awards For Employees                              210
# 536300 - Gifts/Awards For Non-Employees                           79
#
#                                          Financial Unit Number Level 3  \
# Description
# Gift Cards - HS Payments                                          1468
# Employee - Gift/Prize/Award                                       1102
# Non-Employee - Gift/Prize/Award                                    461
# 535100 - Human Subjects (Gift Card)                                242
# 536200 - Gifts/Awards For Employees                                210
# 536300 - Gifts/Awards For Non-Employees                             79
#
#                                          Financial Unit Name Level 3  \
# Description
# Gift Cards - HS Payments                                        1468
# Employee - Gift/Prize/Award                                     1102
# Non-Employee - Gift/Prize/Award                                  461
# 535100 - Human Subjects (Gift Card)                              242
# 536200 - Gifts/Awards For Employees                              210
# 536300 - Gifts/Awards For Non-Employees                           79
#
#                                          Financial Unit Number Level 4  \
# Description
# Gift Cards - HS Payments                                          1468
# Employee - Gift/Prize/Award                                       1102
# Non-Employee - Gift/Prize/Award                                    461
# 535100 - Human Subjects (Gift Card)                                242
# 536200 - Gifts/Awards For Employees                                210
# 536300 - Gifts/Awards For Non-Employees                             79
#
#                                          Financial Unit Name Level 4  \
# Description
# Gift Cards - HS Payments                                        1468
# Employee - Gift/Prize/Award                                     1102
# Non-Employee - Gift/Prize/Award                                  461
# 535100 - Human Subjects (Gift Card)                              242
# 536200 - Gifts/Awards For Employees                              210
# 536300 - Gifts/Awards For Non-Employees                           79
#
#                                          Payment Year
# Description
# Gift Cards - HS Payments                         1468
# Employee - Gift/Prize/Award                      1102
# Non-Employee - Gift/Prize/Award                   461
# 535100 - Human Subjects (Gift Card)               242
# 536200 - Gifts/Awards For Employees               210
# 536300 - Gifts/Awards For Non-Employees            79

# %% [markdown]
# **Splitting the Description Column**: Now that we have found the inconsistencies in our data. We can split the description column into supplier and description. This will allow us to correct those inconsistencies afterwards.

# %%
split_oracle = oracle['Description'].str.split(r'\|\|', n=1, expand=True)
split_oracle.columns = ['Description', 'Supplier']
split_oracle.sample(50)
# Out:
#                                               Description  \
# 538860  522500 - Printed Items and Other Classroom Aid...
# 78803                                               Hotel
# 267123                                       Lab Supplies
# 379991                         Other Minor Equipment <$5K
# 387771                                            Airfare
# 331356                                       Lab Supplies
# 33777                             Transportation Services
# 566461                    522401 - Lab Supplies (taxable)
# 162166                              Professional Services
# 175631                                       Airline Fees
# 576984                        Travel Card Per Diem Offset
# 156820                    Seminar/Conference Registration
# 7645                            Personal/Non-reimbursable
# 580969           522200 - Mail/Postage/Messenger Services
# 537502                     530103 - Audio Visual Services
# 496111                                          Hotel Tax
# 91998                   Conferences and Training (P-Card)
# 513779                                Meals & Incidentals
# 127107                                              Hotel
# 280738                                       Lab Supplies
# 518849                    522401 - Lab Supplies (taxable)
# 125474                Entertainment Meals - Travel Status
# 335655                                         Car Rental
# 20090                                        Lab Supplies
# 536857                Entertainment Meals - Travel Status
# 168441                     Food - Dine In/Delivery/Pickup
# 555260  536400 - (Social Event) Prepared Food/Catering...
# 281679                                Meals & Incidentals
# 345812                Entertainment Meals - Travel Status
# 204920                                       Lab Supplies
# 103273                                       Airline Fees
# 120691                  Conferences and Training (P-Card)
# 350302                                     Human Subjects
# 479606                                          Hotel Tax
# 8423                    Maintenance and Cleaning Supplies
# 131925                           Employee Wearing Apparel
# 538973                                Meals & Incidentals
# 406098                        Group Meals and Incidentals
# 28432                        Other Materials and Supplies
# 65837                                        Lab Supplies
# 46412                                        Lab Supplies
# 144702                  Conferences and Training (P-Card)
# 320246                     Food - Dine In/Delivery/Pickup
# 356458                             Communication Services
# 564224                           Taxi/Shuttle/Car Service
# 30385    Capital Exp - Fabr Cost Excluded From O'Head-Tax
# 194873                                       Airline Fees
# 154543                           Repair Materials & Parts
# 36072                                        Lab Supplies
# 520123        536400 - Social Events and Program Activity
#
#                                                  Supplier
# 538860                             FEDEX OFFICE 800000836
# 78803                                          Courtyards
# 267123                             AMZN MKTP US*HS53E8SN0
# 379991                                       BATTERY MART
# 387771                                    Delta Air Lines
# 331356                             AMZN MKTP US*ZM5VH5PF3
# 33777                                  LYFT   *CANCEL FEE
# 566461                             AMAZON MKTPL*RJ2QW8PT1
# 162166                               UPWORK -511317700REF
# 175631                          AGENT FEE   8900824524954
# 576984                                        SUSHI CROSS
# 156820                             COUNCIL FOR OPPORTUNIT
# 7645                                  GALLIANO RESTAURANT
# 580969                                  FEDEX276996503482
# 537502                                  RIVERSIDEFM, INC.
# 496111                                        HOTEL ZELOS
# 91998                                              GATHER
# 513779                              MAJERLES SPORTS GRILL
# 127107       234661 Harris-Tryon, Tamia A.||Hilton Hotels
# 280738                             AMZN MKTP US*1R5O28SC1
# 518849                                  DKC*DIGI KEY CORP
# 125474                           TST* ACME OYSTER HOUSE -
# 335655                                              Hertz
# 20090                                 ADAFRUIT INDUSTRIES
# 536857                           TST* BOATHOUSE AT HENDRY
# 168441                             BOARD AND BREW DEL MAR
# 555260                           MENDOCINO FARM 15 - LA J
# 281679                            M RESORT RAIDERS TAVERN
# 345812                              TACODELI WESTLAKE 005
# 204920                             AMZN MKTP US*LR36A4CD3
# 103273                          AGENT FEE   8900820546123
# 120691                                BIOPHARMA INSTITUTE
# 350302                            PAYPAL *HERNANDEZSUELY6
# 479606  356748 Adebowale, Omokolade||ESTANCIA HOTEL LO...
# 8423                              MARSHALLS INDSTRL HRDWR
# 131925                                           MEDELITA
# 538973                                      Prince Hotels
# 406098                                     SQ *CAFE DULCE
# 28432                                 THE HOME DEPOT 1848
# 65837                                AMAZON.COM*MV8620N02
# 46412                           INTERNATIONAL ADVANCED MA
# 144702                           SOC FOR NEUROSCIENCE MTG
# 320246                                            TFK UTC
# 356458                                       WISTIA, INC.
# 564224                                         UBER* TRIP
# 30385                                       MCMASTER-CARR
# 194873                          AGENT FEE   8900827065040
# 154543                               ESI SOURCE SOLUTIONS
# 36072                              AMZN MKTP US*SH1M22IW3
# 520123                                 THE HOME DEPOT 680

# %% [markdown]
# ## Cleaning Supplier Names

# %% [markdown]
# The next step in this process is cleaning supplier names and making them consistent. This will help make sure that someone tries and find all entries under a certain supplier, they all show up. This will be done by identifying similar strings and then using replace to replace all of the similar strings with one singular string, so as to categorize them as a certain supplier.

# %% [markdown]
# **Deleting the Payee**: A lot of entries seem to display the payee within the supplier tag. Since we don't need the payee, this step will involve deleting the payee, and taking only the supplier name.

# %%
split_oracle['Supplier'] = split_oracle['Supplier'].apply(lambda x: x.split('||')[-1] if isinstance(x, str) and '||' in x else x)

# %%
split_oracle = split_oracle.sort_values('Supplier')

# %%
split_oracle[split_oracle["Supplier"].str.contains(r"\|\|", na = False)]
# Out:
# Empty DataFrame
# Columns: [Description, Supplier]
# Index: []

# %% [markdown]
# **Finding Suppliers**: This section seeks to find suppliers that need to be replaced by listing suppliers that are repeated more than 20 times.

# %%
counts = split_oracle['Supplier'].value_counts()
entries = counts[counts > 50].index
candidates = split_oracle[split_oracle['Supplier'].isin(entries)].groupby('Supplier').count()
candidates.sample(5)
# Out:
#                            Description
# Supplier
# UCSD PARKING FLEX                   96
# SANDIEGOPADRES                     138
# TRELLO.COM* ATLASSIAN              105
# YOGURT WORLD UCSD                   69
# TST* PACIFIC CAFE & CATER          213

# %% [markdown]
# **Suppliers to Replace**: Lets define a dictionary of regex expressions and suppliers we want to capture under said regex expressions.

# %%
to_replace = {
    r'MARSHALLS.*':'MARSHALLS',
    r'MARSHALLS INDSTRL HRDWR.*':'MARSHALLS INDSTRL HRDWR',
    r'AMZN MKTP.*':'AMAZON MARKETPLACE',
    r'AMZN MAR.*':'AMAZON MARKETPLACE',
    r'AMZN MKTP US.*':'AMAZON MARKETPLACE',
    r'AMZN MKTPL.*':'AMAZON MARKETPLACE',
    r'AMAZON MKTPL.*':'AMAZON MARKETPLACE',
    r'AMAZON GROCE.*':'AMAZON GROCERY',
    r'.*COSTCO.*':'COSTCO',
    r'AMAZON\.COM.*':'AMAZON.COM',
    r'DROPBOX.*':'DROPBOX',
    r'LYFT.*':'LYFT',
    r'THE HOME DEPOT.*':'HOME DEPOT',
    r'TARGET.*': 'TARGET',
    r'VONS.*': 'VONS',
    r'SLACK.*': 'SLACK',
    r'RALPHS.*': 'RALPHS',
    r'EBAY.*': 'EBAY',
    r'UBER TRIP.*': 'UBER',
    r'UBER\* TRIP.*': 'UBER',
    r'STAPLES.*': 'STAPLES',
    r'PANERA BREAD.*': 'PANERA BREAD',
    r'EMIRATES AI.*': 'EMIRATES',
    r'AGENT FEE.*': 'AGENT FEE',
    r'STARBUCKS.*': 'STARBUCKS',
    r'MICHAELS.*': 'MICHAELS',
    r'BEST BUY.*': 'BEST BUY',
    r'AIRBNB.*': 'AIR BNB',
    r'SOUTHWES.*': 'Southwest Airlines',
    r'IN N OUT BURGER.*': 'IN N OUT BURGER',
    r'AIR CHINA.*': 'AIR CHINA',
    r'GRUBHUB.*': 'GRUBHUB',
    r'BOARD AND BREW.*': 'BOARD AND BREW',
    r'HERTZ.*': 'HERTZ',
    r'.*DOORDASH.*': 'DOORDASH',
    r'LOWES.*': 'LOWES',
    r'APPLEBEES.*': 'APPLEBEES',
    r"MCDONALD'S.*": "MCDONALD'S",
    r'FEDEX.*': 'FEDEX',
    r'WESTJETAIR.*': 'West Jet Air',
    r'CORNER BAKERY CAFE.*': 'CORNER BAKERY CAFE',
    r'OFFICE DEPOT.*': 'OFFICE DEPOT',
    r'WALMART.*': 'WALMART',
    r'WAL-MART.*': 'WALMART',
    r'MARRIOT.*': 'Marriot Hotels',
    r'GOOGLE.*': 'GOOGLE',
    r'CHEVRON.*': 'CHEVRON',
    r"DOMINO'S.*": "DOMINO'S",
    r"LINKEDIN ADS.*": "LINKEDIN",
    r"JERSEY MIKES.*": "JERSEY MIKES",
    r"WM.*": "WALMART",
    r"VRBO.*": "VRBO",
    r'BESTBUY.*': 'BEST BUY',
    r'HOMEDEPOT.*': 'HOME DEPOT',
    r'LABCORP.*': 'LABCORP',
    r'QDI.*': 'QUEST DIAGNOSTICS',
    r'AIRCANADA.*': 'AIR CANADA',
    r'\*FINANCE CHARGE.*': 'FINANCE CHARGE',
    r'.*CAVA.*': 'CAVA',
    r'4IMPRINT.*': '4IMPRINT',
    r'7 ELEVEN.*': '7-ELEVEN',
    r'ACE PARKING.*': 'ACE PARKING',
    r'ADDGENE.*': 'ADDGENE',
    r'ADOBE.*': 'ADOBE',
    r'ALASKA AIR.*': 'Alaska Airlines',
    r'AMTRAK.*':'AMTRAK',
    r'ARCO.*':'ARCO',
    r'ATLASSIAN.*':'ATLASSIAN',
    r'AZENTA.*':'AZENTA',
    r'BIO RAD LABORATORIES.*':'BIO RAD LABORATORIES',
    r'BIORENDER.*':'BIORENDER',
    r'CALENDLY.*':'CALENDLY',
    r'CANVA.*':'CANVA',
    r'CHATGPT.*':'OPEN AI',
    r'CHICK-FIL-A.*':'CHICK-FIL-A',
    r'CHIPOTLE.*':'CHIPOTLE',
    r'COPYRIGHT CLEARANCE.*':'COPYRIGHT CLEARANCE',
    r'CHIPOTLE.*':'CHIPOTLE',
    r'CROUTONSUCSD.*':'CROUTONSUCSD',
    r'CUSTOMINK.*':'CUSTOMINK LLC',
    r'Courtyards.*':'Courtyards',
    r'DKC*DIGI KEY CORP.*':'DKC*DIGI KEY CORP',
    r'DUNKIN.*':'DUNKIN',
    r'EINSTEIN BROS.*':'EINSTEIN BROS BAGELS',
    r'EZCATER.*':'EZCATER',
    r'FACEBK.*':'FACEBK',
    r'FEDEX.*':'FEDEX',
    r'FRONTIER.*':'Frontier Airlines',
    r'HAWAIIAN AI.*':'Hawaiian Airlines',
    r'HILTON.*':'Hilton Hotels',
    r'HYATT.*':'Hyatt Hotels',
    r'IC\*.*':'INSTA CART',
    r'IKEA.*':'IKEA',
    r'IN \*COR.*':'IN *COR SECURITY',
    r'INTEGRATED DNA TECH.*':'INTEGRATED DNA TECH',
    r'JETBLUE.*':'Jetblue',
    r'JOBELEPHANT.*':'JOBELEPHANT',
    r'LA JOLLA SHORES HOTEL.*':'LA JOLLA SHORES HOTEL',
    r'LAZ PARKING.*':'LAZ PARKING',
    r'LENOVO.*':'LENOVO',
    r'LIFETECHCORP.*':'LIFETECHCORP',
    r'LINDE GAS.*':'LINDE GAS & EQUIPMENT INC',
    r'LINDEGE.*':'LINDE GAS & EQUIPMENT INC',
    r'LINKEDIN.*':'LINKEDIN',
    r'Lyft.*':'LYFT',
    r'MAILCHIMP.*':'MAILCHIMP',
    r'MENDOCINO FARM.*':'MENDOCINO FARM',
    r'MICROSOFT.*':'MICROSOFT',
    r'National Car Rental.*':'National Car Rental',
    r'OFFICE DEPOT.*':'OFFICE DEPOT',
    r'OPENAI.*':'OPENAI',
    r"PAPA JOHN'S.*":"PAPA JOHN'S",
    r'PAYPAL.*':'PAYPAL TRANSACTION',
    r'PHILLIPS.*':'PHILLIPS',
    r'PRIMORDIUM LABS.*':'PRIMORDIUM LABS',
    r'RENAISSANCE.*':'RENAISSANCE HOTELS',
    r'REPLICA.*':'REPLICA SAN DIEGO',
    r'SANTA CRUZ BIOTECHNOLOGY.*':'SANTA CRUZ BIOTECHNOLOGY',
    r'SHELL.*':'SHELL',
    r'SHERWIN WILLIAMS.*':'SHERWIN WILLIAMS',
    r'SMART AND FINAL.*':'SMART AND FINAL',
    r'SPARK FUN ELECTRONICS.*':'SPARK FUN ELECTRONICS',
    r'SPRINGHILL SUITES.*':'STRINGHILL SUITES',
    r'SQ *BARWORKS CATERING.*':'BARWORKS CATERING',
    r'SQUARESPACE.*':'SQUARESPACE',
    r'STICKER MULE.*':'STICKER MULE',
    r'TECHNICAL SAFETY SERVICES.*':'TECHNICAL SAFETY SERVICES',
    r'THE UPS STORE.*':'UPS',
    r'ULINE.*':'ULINE',
    r'UPS.*':'UPS',
    r'UPWORK.*':'UPWORK',
    r'Uber.*':'UBER',
}

# %% [markdown]
# **The Replacer**: This function will take the above defined dictionary and use it to replace all the values we want it to replace within the dataframe.

# %%
def replacer(df, column, replacements):
    for pattern, replacement in replacements.items():
        df[column] = df[column].str.replace(pattern, replacement, regex=True)
    return df

# %%
final_oracle = replacer(split_oracle, "Supplier", to_replace)
final_oracle.sample(50)
# Out:
#                                               Description  \
# 84861                      Food - Dine In/Delivery/Pickup
# 268841                                       Airline Fees
# 277106                       Other Materials and Supplies
# 419453                                    Office Supplies
# 498201                 522403 - Marine Supplies (taxable)
# 522992                                       Airline Fees
# 181977                   Homeshare - AirBnB / VRBO / Etc.
# 558297                                       Airline Fees
# 137433                    Mail/Postage/Messenger Services
# 143640                  Conferences and Training (P-Card)
# 312679                                          Hotel Tax
# 539510                                          Hotel Tax
# 57361                                             Parking
# 72407                  Comp Software Purchases & Licenses
# 375260                                       Space Rental
# 453631                                          Hotel Tax
# 58620                                        Lab Supplies
# 555487                                            Parking
# 386258                                            Airfare
# 480292                                            Airfare
# 416388                              Professional Services
# 358596                                     Human Subjects
# 476362                     Food - Dine In/Delivery/Pickup
# 2475                                         Lab Supplies
# 562100         522301 - Equipment less than $5K (taxable)
# 291977                              Professional Services
# 433876                            Field Research Supplies
# 138054                                    Office Supplies
# 299756                                    Internet Access
# 174462   Federally Unchargeable Subscriptions/Memberships
# 332953                                       Lab Supplies
# 130597                            Field Research Supplies
# 521732                                Meals & Incidentals
# 279992                                       Lab Supplies
# 492918                     Food - Dine In/Delivery/Pickup
# 501169  522900 - Maintenance and Cleaning Supplies (ta...
# 114929        Social Events and Program Activity (P-Card)
# 224844                            Transportation Services
# 497331                  536700 - Conferences and Training
# 106394                       Other Materials and Supplies
# 339801                                Meals & Incidentals
# 85823                              Communication Services
# 132979                              Printing/Photocopying
# 55546    Federally Unchargeable Subscriptions/Memberships
# 35529                                        Lab Supplies
# 566835  536400 - (Social Event) Prepared Food/Catering...
# 440419               Travel Agent Booking or Service Fees
# 502950                536200 - Gifts/Awards For Employees
# 568908      534002 - Comp Software Purch License Download
# 307963                           Taxi/Shuttle/Car Service
#
#                          Supplier
# 84861      DIRTY BIRDS BAR AND GR
# 268841                  AGENT FEE
# 277106     DICKSSPORTINGGOODS.COM
# 419453                      SLACK
# 498201        CVS/PHARMACY #09926
# 522992                  AGENT FEE
# 181977                       VRBO
# 558297          American Airlines
# 137433            POSTAL PLUS INC
# 143640         PAYPAL TRANSACTION
# 312679            Marriott Hotels
# 539510               Hyatt Hotels
# 57361    PORT OF SD PKG N EMBARCA
# 72407                       SLACK
# 375260     STAXUP STORAGE PORTICO
# 453631               HOTEL MADERA
# 58620          AMAZON MARKETPLACE
# 555487       SDIA AIRPORT PARKING
# 386258            Delta Air Lines
# 480292         Southwest Airlines
# 416388                     UPWORK
# 358596                 AMAZON.COM
# 476362                     COSTCO
# 2475                        FEDEX
# 562100         AMAZON MARKETPLACE
# 291977             AST SYSTEMS US
# 433876               RECONYX, INC
# 138054                 AMAZON.COM
# 299756            THE MISSION INN
# 174462                   CALENDLY
# 332953                      LOWES
# 130597   MURRAY BENJAMIN ELECTRIC
# 521732     JOECOFFEE-CAMPFIRE COF
# 279992                       EBAY
# 492918  SQ *THE BELLA VISTA SOCIA
# 501169             ZORO TOOLS INC
# 114929        99-CENTS-ONLY #0142
# 224844                       LYFT
# 497331  DESIGN FOR HEALTH TRAININ
# 106394                DOLLAR TREE
# 339801                  THAI DISH
# 85823           ATT* BILL PAYMENT
# 132979         AMAZON MARKETPLACE
# 55546        URBAN LAND INSTITUTE
# 35529                  AMAZON.COM
# 566835              Hilton Hotels
# 440419                  AGENT FEE
# 502950                       None
# 568908               FS *MICROMAT
# 307963                UBER   TRIP

# %% [markdown]
# **Adjusting for Description Inconsistencies**: A lot of the gift card invoices should be under the supplier "Gift Card," but instead are listed just as descriptions with a null value as supplier. This next section of code should work to fix that.

# %%
gift_card = [
    'Gift Cards - HS Payments',
    '535100 - Human Subjects (Gift Card)',
    '536200 - Gifts/Awards For Employees',
    '536300 - Gifts/Awards For Non-Employees',
    'Employee - Gift/Prize/Award',
    'Non-Employee - Gift/Prize/Award'
]

# %%
final_oracle.loc[final_oracle['Description'].isin(gift_card), 'Supplier'] = 'Gift Card'

# %% [markdown]
# **Supplier Frequency**: Now that we have cleaned out a lot of the common suppliers, lets group by supplier and see what the distribution of suppliers looks like.

# %%
supplier_frequency = final_oracle.groupby('Supplier').count()

# %% [markdown]
# **Top Suppliers**: What are our top suppliers now?

# %%
supplier_frequency.sort_values('Description', ascending = False).head(50)
# Out:
#                            Description
# Supplier
# AMAZON MARKETPLACE               61951
# AGENT FEE                        36411
# AMAZON.COM                       25076
# LYFT                             15614
# PAYPAL TRANSACTION                7054
# Southwest Airlines                6426
# HOME DEPOT                        6321
# MCMASTER-CARR                     5976
# United Airlines                   5769
# TARGET                            5756
# FEDEX                             5376
# COSTCO                            5107
# Hilton Hotels                     4316
# Marriott Hotels                   4205
# Gift Card                         4149
# Alaska Airlines                   4145
# Hyatt Hotels                      3762
# American Airlines                 3755
# UBER   TRIP                       3564
# Delta Air Lines                   3372
# ADOBE                             3164
# ESTANCIA HOTEL LODGING            2985
# EBAY                              2889
# Sheraton                          2880
# RALPHS                            2836
# STARBUCKS                         2672
# FACEBK                            2548
# LA JOLLA SHORES HOTEL             2366
# WALMART                           2320
# GOOGLE                            2317
# LINDE GAS & EQUIPMENT INC         2091
# SLACK                             1912
# DKC*DIGI KEY CORP                 1855
# DOORDASH                          1783
# DROPBOX                           1652
# EZCATER                           1605
# UPS                               1561
# MENDOCINO FARM                    1527
# Courtyards                        1481
# VONS                              1446
# APPLE.COM/US                      1439
# UPWORK                            1393
# EINSTEIN BROS BAGELS              1368
# Enterprise                        1360
# STAPLES                           1321
# BEST BUY                          1319
# DOMINO'S                          1308
# Residence Inns                    1257
# MAILCHIMP                         1238
# Hertz                             1207

# %% [markdown]
# **What Suppliers are billing the most?**:

# %%
oracle['Invoice Distribution Amount'] = oracle['Invoice Distribution Amount'].astype(float)
final_oracle['Invoice Distribution Amount'] = oracle['Invoice Distribution Amount']

# %%
supplier_total = final_oracle.groupby('Supplier').sum()
supplier_total.sort_values('Invoice Distribution Amount', ascending = False).head(50)
# Out:
#                         Invoice Distribution Amount
# Supplier
# AMAZON MARKETPLACE                       6981027.10
# JAX                                      6731621.86
# Residence Inns                           6319019.11
# VERIZONWRLSS*RTCCR VB                    6163805.95
# Gift Card                                5193442.20
# Marriott Hotels                          4890366.59
# United Airlines                          4477189.89
# AMAZON.COM                               3738252.24
# PAYPAL TRANSACTION                       3301616.87
# Hilton Hotels                            3176071.81
# Southwest Airlines                       3029945.60
# American Airlines                        2861538.28
# ATT*BILL PAYMENT                         2806896.17
# CHARLES RIVER LAB                        2601075.68
# MCMASTER-CARR                            2504426.35
# Delta Air Lines                          2354078.07
# APPLE.COM/US                             1957661.15
# Sheraton                                 1955366.95
# Hyatt Hotels                             1913919.14
# SUN DIEGO CHARTER                        1770773.23
# Alaska Airlines                          1692740.39
# HOME DEPOT                               1553320.11
# VZWRLSS*IVR VB                           1544080.04
# Courtyards                               1517455.39
# COSTCO                                   1460721.04
# LA JOLLA SHORES HOTEL                    1170470.67
# FACEBK                                   1119877.52
# UNITED VAN LINES                         1115999.57
# VANILLAGIFT.COM                          1075963.54
# EBAY                                     1068410.36
# COPYRIGHT CLEARANCE                      1068197.59
# ESTANCIA HOTEL LODGING                   1031419.65
# ESTANCIA HOTEL SERTIFI                    918431.63
# 4IMPRINT                                  859239.06
# ULINE                                     816876.69
# AIR BNB                                   807692.90
# DMI* DELL BUS ONLINE                      798601.20
# EZCATER                                   762304.47
# WALMART                                   743659.24
# DKC*DIGI KEY CORP                         742177.71
# MENDOCINO FARM                            724583.38
# STRINGHILL SUITES                         724236.06
# United                                    715640.93
# B&H PHOTO 800-606-6969                    708357.78
# BEST BUY                                  682258.14
# LYFT                                      669022.08
# GOOGLE                                    669019.36
# ELSEVIER INC.                             666818.60
# FEDEX                                     646275.10
# JOBELEPHANT                               620255.93

# %% [markdown]
# ## Statistics: How well is the cleaning doing?

# %% [markdown]
# ### How are we doing in terms of amount of invoices?

# %% [markdown]
# In this section I will look solely at the suppliers I have replaced and access what portion of the overall amount of data they make up, so as to access how well the cleaning process is going.

# %% [markdown]
# **How many invoices are there?:** Here we will take a look at how many invoices we have total.

# %%
num_invoices = supplier_frequency["Description"].sum()
num_invoices
# Out:
# 581406

# %% [markdown]
# **How many invoices did we take care of?**: Here I will access how many invoices the data cleaning above took care of.

# %%
regex_invoices = final_oracle.loc[final_oracle['Supplier'].isin(to_replace.values())]
total_regex = regex_invoices.shape[0]
total_regex
# Out:
# 267088

# %%
giftcard_invoices = final_oracle.loc[final_oracle['Description'].isin(gift_card)]
total_giftcard = giftcard_invoices.shape[0]
total_giftcard
# Out:
# 4149

# %%
total = total_regex + total_giftcard
total
# Out:
# 271237

# %% [markdown]
# **What percent of invoices did we capture?**: Of the total amount of invoices, what percent is directly accounted for through modification in this notebook?

# %%
(total/num_invoices) * 100
# Out:
# 46.651909337020946

# %% [markdown]
# **What does this mean?**: While this is a low percentage, it is important to remember that a lot of the invoices could have been already grouped properly meaning that there was no cleaning required. This means that the number is likely a lot higher than the 33 percent we are getting from solely the data that I explictly replaced using regex and manual inputation.

# %% [markdown]
# ### How are we doing in terms of total spend accounted for?

# %% [markdown]
# In this section I will assess how well the cleaning process is working through looking at how much of total spend is accounted for by the cleaned suppliers. This will give us an alternative way of measuring success.

# %% [markdown]
# **What is the total spend this month?**: In this section I will be looking at the total spend this month. To do this, I will have to filter out the dataset to only get rows from this month, then total up the "Invoice Distribution Amount.

# %%
final_oracle['Payment Date'] = oracle['Payment Date']

# %%
final_oracle['Payment Date'] = pd.to_datetime(final_oracle["Payment Date"])

# %%
start_date = pd.to_datetime("2023-07-01").tz_localize('UTC')
end_date = pd.to_datetime("2024-06-30").tz_localize('UTC')

this_year = final_oracle[(final_oracle['Payment Date'] >= start_date) & (final_oracle['Payment Date'] <= end_date)]

# %%
this_year.head()
# Out:
#                          Description                Supplier  \
# 417362           Meals & Incidentals  #03 CAP CITY GRANDVIEW
# 430820           Meals & Incidentals  #03 CAP CITY GRANDVIEW
# 317243  Other Materials and Supplies  #04 LAKESHORE LEARNING
# 407391  Other Materials and Supplies  #04 LAKESHORE LEARNING
# 369236  Other Materials and Supplies  #04 LAKESHORE LEARNING
#
#         Invoice Distribution Amount              Payment Date
# 417362                        31.78 2023-12-21 00:00:00+00:00
# 430820                        28.74 2024-01-19 00:00:00+00:00
# 317243                        83.92 2023-07-05 00:00:00+00:00
# 407391                        79.78 2023-12-08 00:00:00+00:00
# 369236                       296.72 2023-10-08 00:00:00+00:00

# %%
total_spend = this_year['Invoice Distribution Amount'].sum()
total_spend
# Out:
# 95181821.93

# %% [markdown]
# **How much spend did we capture**: How much spend did we capture within the invoices cleaned through this notebook?

# %%
regex_invoices_spend = sum(this_year.loc[this_year['Supplier'].isin(to_replace.values())]['Invoice Distribution Amount'])
regex_invoices_spend
# Out:
# 22066717.75000041

# %%
giftcard_invoices_spend = sum(this_year.loc[this_year['Description'].isin(gift_card)]['Invoice Distribution Amount'])
giftcard_invoices_spend
# Out:
# 1700909.59

# %%
spend_sum = regex_invoices_spend + giftcard_invoices_spend
spend_sum
# Out:
# 23767627.34000041

# %% [markdown]
# **What percentage of spend did we capture?**: What percent of the total spend is taken care of by invoices that were cleaned using this notebook?

# %%
spend_percent = (spend_sum / total_spend) * 100
spend_percent
# Out:
# 24.97076317522052

# %% [markdown]
# ## Exporting our subset of the data

# %% [markdown]
# In this section there will be code to export the subsection of the data we worked with in the statistics section. That will allow for further analysis and collaboration. Note: this is not the final export with the data needed for inputation into tableau, but rather a checkpoint export.

# %%
final_oracle['Invoice Creation Date'] = pd.to_datetime(oracle["Invoice Creation Date"])

# %%
final_oracle['Supplier Invoice Date'] = pd.to_datetime(oracle["Supplier Invoice Date"])

# %%
final_oracle['Invoice ID'] = oracle['Invoice ID']
final_oracle[['Invoice Source',
              'Invoice Number', 
              'Payment Method Code', 
              'Payment Number', 
              'Supplier Type',
              'Financial Unit',
              'Financial Unit Number',
              'Financial Unit Number Level 2',
              'Financial Unit Name Level 2',
              'Financial Unit Number Level 3',
              'Financial Unit Name Level 3',
              'Financial Unit Number Level 4',
              'Financial Unit Name Level 4',
              'Payment Year'
             ]] = oracle[['Invoice Source',
              'Invoice Number', 
              'Payment Method Code', 
              'Payment Number', 
              'Supplier Name',
              'Financial Unit',
              'Financial Unit Number',
              'Financial Unit Number Level 2',
              'Financial Unit Name Level 2',
              'Financial Unit Number Level 3',
              'Financial Unit Name Level 3',
              'Financial Unit Number Level 4',
              'Financial Unit Name Level 4',
              'Payment Year']]
final_oracle = final_oracle[['Invoice ID',
                   'Invoice Number', 
                   'Invoice Source', 
                   'Description',
                'Supplier',
                   'Invoice Distribution Amount', 
                   'Invoice Creation Date',
                   'Supplier Invoice Date',
                   'Payment Date',
                   'Payment Method Code',
                   'Payment Number',
                   'Supplier Type',
                   'Financial Unit',
                   'Financial Unit Number',
                   'Financial Unit Number Level 2',
                   'Financial Unit Name Level 2',
                   'Financial Unit Number Level 3',
                   'Financial Unit Name Level 3',
                   'Financial Unit Number Level 4',
                   'Financial Unit Name Level 4',
                   'Payment Year']]

# %% [markdown]
# **Adding Card Types**: I will proceed to distinguish if an invoice is from a travel card or a P-Card transaction.

# %%
final_oracle['Category'] = final_oracle['Invoice Number'].apply(lambda x: 'Travel' if '_T_' in x else 'Procurement' if '_P_' in x else 'Unknown')
# Out:
# /var/folders/f7/jyxy75m95bdc7p3xqgwf_zyh0000gn/T/ipykernel_23229/554851063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_oracle['Category'] = final_oracle['Invoice Number'].apply(lambda x: 'Travel' if '_T_' in x else 'Procurement' if '_P_' in x else 'Unknown')

# %% [markdown]
# **In Progress**: Working on adding emails and addition information straight from Concur. Don't worry about this section as of now, will be updated in the near future.

# %%
expenses = pd.read_csv('Concur Data.csv', encoding='utf-16')
expenses.head()
# Out:
#   TE User ID        TE User Name Full     Expense Report ID  \
# 0   10360455        Lee, Ellen Eun-Ok  864DDE3F8C2D4ABB8026
# 1   10362988     Shabkie, Donna Marie  673422E24F5946558728
# 2   10432699            Tamrat, Tihut  00B2A02908B34CAABFD0
# 3   10359672     Reyes, Rebecca Ellen  7D4A6363B53D4183BF24
# 4   10358900  Cardenas, Daniel Joseph  F797CDC66AF544AB8A9C
#
#   TE User Email Address                               Expense Report Type  \
# 0       eel013@ucsd.edu                (Legacy) Procurement Card Expenses
# 1     dshabkie@ucsd.edu  (Legacy) Event Expenses and Other Reimbursements
# 2     titamrat@ucsd.edu                (Legacy) Procurement Card Expenses
# 3       rer010@ucsd.edu                (Legacy) Procurement Card Expenses
# 4   djcardenas@ucsd.edu                (Legacy) Procurement Card Expenses
#
#   Expense Report Payment Status Expense Report Sent for Payment DateTime  \
# 0              Sent for Payment                      2023-05-20 02:45:04
# 1              Sent for Payment                      2023-05-05 02:36:57
# 2              Sent for Payment                      2020-12-05 04:29:53
# 3              Sent for Payment                      2022-05-24 02:11:08
# 4              Sent for Payment                      2023-04-26 02:48:15
#
#    Expense Report Key
# 0              318573
# 1              304767
# 2               38493
# 3              180972
# 4              292489

# %%
requests = pd.read_csv('requests.csv', encoding = 'utf-16')
requests.head()
# Out:
#   TE User ID   TE User Name Full TE Request ID TE User Email Address  \
# 0   10407986  Engler, Anne-Marie          3TQV     amengler@ucsd.edu
# 1   10578843         Pierce, Meg          6XDC     mcpierce@ucsd.edu
# 2   10373170   Triplett, Cynthia          3U6X       cyc077@ucsd.edu
# 3   10417488     Thompson, Sheri          6KCE       skt007@ucsd.edu
# 4   10578843         Pierce, Meg          6XD9     mcpierce@ucsd.edu
#
#                             TE Request Type TE Request Approval Status  \
# 0  (Legacy) Card & Payment Products Request                   Approved
# 1  (Legacy) Card & Payment Products Request                   Approved
# 2  (Legacy) Card & Payment Products Request                   Approved
# 3  (Legacy) Card & Payment Products Request                   Approved
# 4  (Legacy) Card & Payment Products Request                   Approved
#
#   TE Request First Approved DateTime
# 0                2021-01-21 01:35:33
# 1                2022-07-07 15:55:12
# 2                2021-01-28 22:27:15
# 3                2022-05-02 21:57:06
# 4                2022-07-07 15:24:48

# %%
final_oracle['Extracted_Invoice_Number'] = final_oracle['Invoice Number'].apply(lambda x: x.split('_')[1] if isinstance(x, str) else None)
# Out:
# /var/folders/f7/jyxy75m95bdc7p3xqgwf_zyh0000gn/T/ipykernel_23229/351295459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_oracle['Extracted_Invoice_Number'] = final_oracle['Invoice Number'].apply(lambda x: x.split('_')[1] if isinstance(x, str) else None)

# %%
merged_1_2 = pd.merge(final_oracle, expenses, left_on='Extracted_Invoice_Number', right_on = 'Expense Report ID', how='left')

# %%
final_merged = pd.merge(merged_1_2, requests, left_on ='Extracted_Invoice_Number', right_on='TE Request ID', how='left', suffixes = ('','_t3'))

# %%
final_merged.columns
# Out:
# Index(['Invoice ID', 'Invoice Number', 'Invoice Source', 'Description',
#        'Supplier', 'Invoice Distribution Amount', 'Invoice Creation Date',
#        'Supplier Invoice Date', 'Payment Date', 'Payment Method Code',
#        'Payment Number', 'Supplier Type', 'Financial Unit',
#        'Financial Unit Number', 'Financial Unit Number Level 2',
#        'Financial Unit Name Level 2', 'Financial Unit Number Level 3',
#        'Financial Unit Name Level 3', 'Financial Unit Number Level 4',
#        'Financial Unit Name Level 4', 'Payment Year', 'Category',
#        'Extracted_Invoice_Number', 'TE User ID', 'TE User Name Full',
#        'Expense Report ID', 'TE User Email Address', 'Expense Report Type',
#        'Expense Report Payment Status',
#        'Expense Report Sent for Payment DateTime', 'Expense Report Key',
#        'TE User ID_t3', 'TE User Name Full_t3', 'TE Request ID',
#        'TE User Email Address_t3', 'TE Request Type',
#        'TE Request Approval Status', 'TE Request First Approved DateTime'],
#       dtype='object')

# %%
final_merged['TE User ID'] = final_merged['TE User ID'].combine_first(final_merged['TE User ID_t3'])

# %%
final_merged['TE User Name Full'] = final_merged['TE User Name Full'].combine_first(final_merged['TE User Name Full_t3'])

# %%
final_merged['TE User Email Address'] = final_merged['TE User Email Address'].combine_first(final_merged['TE User Email Address_t3'])

# %%
final_merged = final_merged.drop(columns=['TE User ID_t3', 'TE User Name Full_t3', 'TE User Email Address_t3'])

# %%
final_merged
# Out:
#        Invoice ID                                 Invoice Number  \
# 0         5822802            TE_061C5C8DC5404E51A54F_T_MrozSusan
# 1         5969721      TE_53521EDEE1DF4778A224_T_GermainBenjamin
# 2         4886767  TE_527F1C82BBF141049C60_P_Bussey-NealVictoria
# 3         4273727  TE_5DAFEC2470084F6CA802_P_Fortune-GradyRegina
# 4         3435346            TE_5751852CF4AE420F86DB_P_EdditPaje
# ...           ...                                            ...
# 581541    6831585                          TE_LRN9_G_HaightMarta
# 581542    6831586                           TE_LRVT_G_SwanAshley
# 581543    6837744                           TE_LRWV_G_HillParisa
# 581544    6837745                            TE_LT3X_G_PatelSean
# 581545    6837746                       TE_LWWF_G_HernandezAlexa
#
#        Invoice Source                          Description  \
# 0         UCSD Concur                  Meals & Incidentals
# 1         UCSD Concur                  Meals & Incidentals
# 2         UCSD Concur                      Office Supplies
# 3         UCSD Concur         Other Materials and Supplies
# 4         UCSD Concur                      Office Supplies
# ...               ...                                  ...
# 581541    UCSD Concur  535100 - Human Subjects (Gift Card)
# 581542    UCSD Concur  535100 - Human Subjects (Gift Card)
# 581543    UCSD Concur  535100 - Human Subjects (Gift Card)
# 581544    UCSD Concur  535100 - Human Subjects (Gift Card)
# 581545    UCSD Concur  535100 - Human Subjects (Gift Card)
#
#                       Supplier  Invoice Distribution Amount  \
# 0       #03 CAP CITY GRANDVIEW                        31.78
# 1       #03 CAP CITY GRANDVIEW                        28.74
# 2       #04 LAKESHORE LEARNING                       268.60
# 3       #04 LAKESHORE LEARNING                       237.56
# 4       #04 LAKESHORE LEARNING                        77.57
# ...                        ...                          ...
# 581541               Gift Card                      1020.00
# 581542               Gift Card                      5121.00
# 581543               Gift Card                       260.00
# 581544               Gift Card                      3800.00
# 581545               Gift Card                      3550.00
#
#            Invoice Creation Date     Supplier Invoice Date  \
# 0      2023-12-20 07:11:14+00:00 2023-11-20 00:00:00+00:00
# 1      2024-01-18 04:10:19+00:00 2023-09-30 00:00:00+00:00
# 2      2023-06-03 03:15:50+00:00 2023-04-12 00:00:00+00:00
# 3      2023-02-25 04:06:43+00:00 2023-02-05 00:00:00+00:00
# 4      2022-08-26 03:06:27+00:00 2022-07-28 00:00:00+00:00
# ...                          ...                       ...
# 581541 2024-08-28 03:11:21+00:00 2024-08-28 00:00:00+00:00
# 581542 2024-08-28 03:11:21+00:00 2024-08-28 00:00:00+00:00
# 581543 2024-08-29 03:11:17+00:00 2024-08-29 00:00:00+00:00
# 581544 2024-08-29 03:11:17+00:00 2024-08-29 00:00:00+00:00
# 581545 2024-08-29 03:11:17+00:00 2024-08-29 00:00:00+00:00
#
#                     Payment Date Payment Method Code  ...  \
# 0      2023-12-21 00:00:00+00:00                  TC  ...
# 1      2024-01-19 00:00:00+00:00                  TC  ...
# 2      2023-06-04 00:00:00+00:00                  EC  ...
# 3      2023-02-26 00:00:00+00:00                  EC  ...
# 4      2022-08-27 00:00:00+00:00                  EC  ...
# ...                          ...                 ...  ...
# 581541 2024-08-29 00:00:00+00:00                Gift  ...
# 581542 2024-08-29 00:00:00+00:00                Gift  ...
# 581543 2024-08-30 00:00:00+00:00                Gift  ...
# 581544 2024-08-30 00:00:00+00:00                Gift  ...
# 581545 2024-08-30 00:00:00+00:00                Gift  ...
#
#            Expense Report ID    TE User Email Address  \
# 0       061C5C8DC5404E51A54F          smmroz@ucsd.edu
# 1       53521EDEE1DF4778A224        bgermain@ucsd.edu
# 2       527F1C82BBF141049C60     vbusseyneal@ucsd.edu
# 3       5DAFEC2470084F6CA802  refortunegrady@ucsd.edu
# 4       5751852CF4AE420F86DB           epaje@ucsd.edu
# ...                      ...                      ...
# 581541                   NaN         mhaight@ucsd.edu
# 581542                   NaN           arobb@ucsd.edu
# 581543                   NaN          pmhill@ucsd.edu
# 581544                   NaN          svp004@ucsd.edu
# 581545                   NaN    ahernandez04@ucsd.edu
#
#                        Expense Report Type Expense Report Payment Status  \
# 0                 (Legacy) Travel Expenses              Sent for Payment
# 1                 (Legacy) Travel Expenses              Sent for Payment
# 2       (Legacy) Procurement Card Expenses              Sent for Payment
# 3       (Legacy) Procurement Card Expenses              Sent for Payment
# 4       (Legacy) Procurement Card Expenses              Sent for Payment
# ...                                    ...                           ...
# 581541                                 NaN                           NaN
# 581542                                 NaN                           NaN
# 581543                                 NaN                           NaN
# 581544                                 NaN                           NaN
# 581545                                 NaN                           NaN
#
#        Expense Report Sent for Payment DateTime Expense Report Key  \
# 0                           2023-12-20 06:58:58           399234.0
# 1                           2024-01-18 03:53:47           397506.0
# 2                           2023-06-03 02:40:33           309206.0
# 3                           2023-02-25 03:35:07           283003.0
# 4                           2022-08-26 02:29:07           215365.0
# ...                                         ...                ...
# 581541                                      NaN                NaN
# 581542                                      NaN                NaN
# 581543                                      NaN                NaN
# 581544                                      NaN                NaN
# 581545                                      NaN                NaN
#
#        TE Request ID                      TE Request Type  \
# 0                NaN                                  NaN
# 1                NaN                                  NaN
# 2                NaN                                  NaN
# 3                NaN                                  NaN
# 4                NaN                                  NaN
# ...              ...                                  ...
# 581541          LRN9  Gift Cards & Human Subject Payments
# 581542          LRVT  Gift Cards & Human Subject Payments
# 581543          LRWV  Gift Cards & Human Subject Payments
# 581544          LT3X  Gift Cards & Human Subject Payments
# 581545          LWWF  Gift Cards & Human Subject Payments
#
#        TE Request Approval Status TE Request First Approved DateTime
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ...                           ...                                ...
# 581541                   Approved                2024-08-21 23:23:59
# 581542                   Approved                2024-08-22 20:36:27
# 581543                   Approved                2024-08-22 21:12:54
# 581544                   Approved                2024-08-23 15:21:07
# 581545                   Approved                2024-08-27 19:45:50
#
# [581546 rows x 35 columns]

# %%
final_oracle['Invoice Distribution Amount'].sum()
# Out:
# 255770223.4100001

# %%
final_merged['Invoice Distribution Amount'].sum()
# Out:
# 255770223.4100001

# %%
final_merged.to_csv('Concur Final Merged.csv')
